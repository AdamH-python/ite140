# %%
import pandas as pd

# %% [markdown]
# # Bringing in dat data

# %%
stocks = pd.read_excel("Stocks Data.xlsx")

# %% [markdown]
# ## Print a little bit of the table

# %%
stocks
# Out:
#        symbol       date      open      high       low     close    volume
# 0         AAL 2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943
# 1        AAPL 2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957
# 2         AAP 2014-01-02  110.3600  111.8800  109.2900  109.7400    542711
# 3        ABBV 2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061
# 4         ABC 2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391
# ...       ...        ...       ...       ...       ...       ...       ...
# 497467    XYL 2017-12-29   68.5300   68.8000   67.9200   68.2000   1046677
# 497468    YUM 2017-12-29   82.6400   82.7100   81.5900   81.6100   1347613
# 497469    ZBH 2017-12-29  121.7500  121.9500  120.6200  120.6700   1023624
# 497470   ZION 2017-12-29   51.2800   51.5500   50.8100   50.8300   1261916
# 497471    ZTS 2017-12-29   72.5500   72.7600   72.0400   72.0400   1704122
#
# [497472 rows x 7 columns]

# %% [markdown]
# ## Check the datatypes

# %%
stocks.dtypes
# Out:
# symbol            object
# date      datetime64[ns]
# open             float64
# high             float64
# low              float64
# close            float64
# volume             int64
# dtype: object

# %% [markdown]
# ## Setting Correct Datatypes

# %%
stocks = stocks.astype({"symbol": "string"})

# %% [markdown]
# ## Looking at some Summary Data

# %%
stocks.loc[:,"close"].mean()
# Out:
# 86.36908207456902

# %%
stocks.loc[:, "high"].max()
# Out:
# 2067.99

# %%
stocks.loc[:, "low"].min()
# Out:
# 1.5

# %% [markdown]
# ## Adding a Name to the Index

# %%
stocks.index.name = "stock #"

stocks
# Out:
#         symbol       date      open      high       low     close    volume
# stock #
# 0          AAL 2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943
# 1         AAPL 2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957
# 2          AAP 2014-01-02  110.3600  111.8800  109.2900  109.7400    542711
# 3         ABBV 2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061
# 4          ABC 2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391
# ...        ...        ...       ...       ...       ...       ...       ...
# 497467     XYL 2017-12-29   68.5300   68.8000   67.9200   68.2000   1046677
# 497468     YUM 2017-12-29   82.6400   82.7100   81.5900   81.6100   1347613
# 497469     ZBH 2017-12-29  121.7500  121.9500  120.6200  120.6700   1023624
# 497470    ZION 2017-12-29   51.2800   51.5500   50.8100   50.8300   1261916
# 497471     ZTS 2017-12-29   72.5500   72.7600   72.0400   72.0400   1704122
#
# [497472 rows x 7 columns]

# %% [markdown]
# ## Adding a new column for the Total Value, also called the Market Cap

# %%
stocks.loc[:, "total value"] = stocks.loc[:, "close"] * stocks.loc[:, "volume"]
stocks
# Out:
#         symbol       date      open      high       low     close    volume  \
# stock #
# 0          AAL 2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943
# 1         AAPL 2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957
# 2          AAP 2014-01-02  110.3600  111.8800  109.2900  109.7400    542711
# 3         ABBV 2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061
# 4          ABC 2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391
# ...        ...        ...       ...       ...       ...       ...       ...
# 497467     XYL 2017-12-29   68.5300   68.8000   67.9200   68.2000   1046677
# 497468     YUM 2017-12-29   82.6400   82.7100   81.5900   81.6100   1347613
# 497469     ZBH 2017-12-29  121.7500  121.9500  120.6200  120.6700   1023624
# 497470    ZION 2017-12-29   51.2800   51.5500   50.8100   50.8300   1261916
# 497471     ZTS 2017-12-29   72.5500   72.7600   72.0400   72.0400   1704122
#
#           total value
# stock #
# ...

# %% [markdown]
# ## Looking at all the occurences of Apple Stocks, with the symbol AAPL

# %%
apple_stock = stocks[stocks.symbol == "AAPL"]
apple_stock
# Out:
#         symbol       date      open      high       low     close     volume  \
# stock #
# 1         AAPL 2014-01-02   79.3828   79.5756   78.8601   79.0185   58791957
# 484       AAPL 2014-01-03   78.9799   79.0999   77.2042   77.2828   98303870
# 967       AAPL 2014-01-06   76.7785   78.1142   76.2285   77.7042  103359151
# 1450      AAPL 2014-01-07   77.7599   77.9942   76.8464   77.1481   79432766
# 1933      AAPL 2014-01-08   76.9728   77.9371   76.9556   77.6371   64686685
# ...        ...        ...       ...       ...       ...       ...        ...
# 494948    AAPL 2017-12-22  174.6800  175.4240  174.5000  175.0100   16349444
# 495453    AAPL 2017-12-26  170.8000  171.4700  169.6790  170.5700   33185536
# 495958    AAPL 2017-12-27  170.1000  170.7800  169.7100  170.6000   21498213
# 496463    AAPL 2017-12-28  171.0000  171.8500  170.4800  171.0800   16480187
# 496968    AAPL 2017-12-29  170.5200  170.5900  169.2200  169.2300   25999922
#
#           total value
# stock #
# ...

# %% [markdown]
# ## Looking at all the Unique Stock Symbols the First Time They Appear

# %%
unique_stocks = stocks.drop_duplicates(["symbol"])
unique_stocks
# Out:
#         symbol       date      open      high       low     close    volume  \
# stock #
# 0          AAL 2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943
# 1         AAPL 2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957
# 2          AAP 2014-01-02  110.3600  111.8800  109.2900  109.7400    542711
# 3         ABBV 2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061
# 4          ABC 2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391
# ...        ...        ...       ...       ...       ...       ...       ...
# 402586     DXC 2017-04-03   69.3200   71.8300   67.7600   67.9500  34496800
# 434068    BHGE 2017-07-03   55.0000   57.7300   54.5700   57.6800   4124512
# 438586     BHF 2017-07-17   75.0000   75.0000   70.0000   70.0000     33982
# 455771    DWDP 2017-09-01   66.6600   67.3000   65.6600   67.1800   7341133
# 488429    APTV 2017-12-05   88.8900   89.6600   86.1600   88.7700   3522147
#
#           total value
# stock #
# ...

# %% [markdown]
# ## I Tried to Find the Last occurence of the Stock, but That Didn't Really Work

# %%
unique_last = stocks.drop_duplicates(["symbol"]).duplicated(keep="last")
unique_last
# Out:
# stock #
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 402586    False
# 434068    False
# 438586    False
# 455771    False
# 488429    False
# Length: 505, dtype: bool
